# %% [markdown]
# <a href="https://colab.research.google.com/github/faznafathima/__PROJECTS__/blob/main/Multiclass_svm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MULTICLASS SVM ON IRIS DATASET**

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r'/content/IRIS.csv')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
pd.get_dummies(data,columns=['species'])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  \
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
#      species_Iris-setosa  species_Iris-versicolor  species_Iris-virginica
# 0                      1                        0                       0
# 1                      1                        0                       0
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(data.drop('species',axis=1))
scaled_features = scaler.transform(data.drop('species',axis=1))
data_scaled = pd.DataFrame(scaled_features,columns=data.columns[:-1])
data_scaled.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0     -0.900681     1.032057     -1.341272    -1.312977
# 1     -1.143017    -0.124958     -1.341272    -1.312977
# 2     -1.385353     0.337848     -1.398138    -1.312977
# 3     -1.506521     0.106445     -1.284407    -1.312977
# 4     -1.021849     1.263460     -1.341272    -1.312977
# 5     -0.537178     1.957669     -1.170675    -1.050031
# 6     -1.506521     0.800654     -1.341272    -1.181504
# 7     -1.021849     0.800654     -1.284407    -1.312977
# 8     -1.748856    -0.356361     -1.341272    -1.312977
# 9     -1.143017     0.106445     -1.284407    -1.444450

# %%
X=data_scaled
y=data['species']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score,accuracy_score,recall_score,f1_score,mean_absolute_error,mean_squared_error

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 50, test_size = 0.25)

# %%
y_test.value_counts()
# Out:
# Iris-versicolor    15
# Iris-virginica     12
# Iris-setosa        11
# Name: species, dtype: int64

# %%
from sklearn.svm import SVC
model=SVC()
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       0.93      0.93      0.93        15
#  Iris-virginica       0.92      0.92      0.92        12
#
#        accuracy                           0.95        38
#       macro avg       0.95      0.95      0.95        38
#    weighted avg       0.95      0.95      0.95        38
